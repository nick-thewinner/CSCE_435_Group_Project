# %% [markdown]
# # Group Project Thicket Python Code

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("Bitonic_Input_Type_Random/*.cali"))

# %%
# Performance data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              93982112      1
#                                                   102060332     1
#                                                   352801846     1
#                                                   1010932979    1
#                                                   1178430311    1
#                                                   1258916736    1
#                                                   1423590944    1
#                                                   1532780983    1
#                                                   1917893285    1
#                                                   3126498597    1
#                                                   3964765198    1
#                                                   3969520793    1
#                                                   4009217263    1
#                                                   4100248998    1
#                                                   4238799154    1
# {'name': 'comm', 'type': 'function'}              93982112      3
#                                                   102060332     3
#                                                   352801846     3
#                                                   1010932979    3
#                                                   1178430311    3
#                                                   1258916736    3
#                                                   1423590944    3
#                                                   1532780983    3
#                                                   1917893285    3
#                                                   3126498597    3
#                                                   3964765198    3
#                                                   3969520793    3
#                                                   4009217263    3
#                                                   4100248998    3
#                                                   4238799154    3
# {'name': 'comm_large', 'type': 'function'}        93982112      4
#                                                   102060332     4
#                                                   352801846     4
#                                                   1010932979    4
#                                                   1178430311    4
#                                                   1258916736    4
#                                                   1423590944    4
#                                                   1532780983    4
#                                                   1917893285    4
#                                                   3126498597    4
#                                                   3964765198    4
#                                                   3969520793    4
#                                                   4009217263    4
#                                                   4100248998    4
#                                                   4238799154    4
# {'name': 'cudaMemcpy', 'type': 'function'}        93982112      5
#                                                   102060332     5
#                                                   352801846     5
#                                                   1010932979    5
#                                                   1178430311    5
#                                                   1258916736    5
#                                                   1423590944    5
#                                                   1532780983    5
#                                                   1917893285    5
#                                                   3126498597    5
#                                                   3964765198    5
#                                                   3969520793    5
#                                                   4009217263    5
#                                                   4100248998    5
#                                                   4238799154    5
# {'name': 'comp', 'type': 'function'}              93982112      6
#                                                   102060332     6
#                                                   352801846     6
#                                                   1010932979    6
#                                                   1178430311    6
#                                                   1258916736    6
#                                                   1423590944    6
#                                                   1532780983    6
#                                                   1917893285    6
#                                                   3126498597    6
#                                                   3964765198    6
#                                                   3969520793    6
#                                                   4009217263    6
#                                                   4100248998    6
#                                                   4238799154    6
# {'name': 'comp_large', 'type': 'function'}        93982112      7
#                                                   102060332     7
#                                                   352801846     7
#                                                   1010932979    7
#                                                   1178430311    7
#                                                   1258916736    7
#                                                   1423590944    7
#                                                   1532780983    7
#                                                   1917893285    7
#                                                   3126498597    7
#                                                   3964765198    7
#                                                   3969520793    7
#                                                   4009217263    7
#                                                   4100248998    7
#                                                   4238799154    7
# {'name': 'correctness_check', 'type': 'function'} 93982112      8
#                                                   102060332     8
#                                                   352801846     8
#                                                   1010932979    8
#                                                   1178430311    8
#                                                   1258916736    8
#                                                   1423590944    8
#                                                   1532780983    8
#                                                   1917893285    8
#                                                   3126498597    8
#                                                   3964765198    8
#                                                   3969520793    8
#                                                   4009217263    8
#                                                   4100248998    8
#                                                   4238799154    8
# {'name': 'data_init', 'type': 'function'}         93982112      2
#                                                   102060332     2
#                                                   352801846     2
#                                                   1010932979    2
#                                                   1178430311    2
#                                                   1258916736    2
#                                                   1423590944    2
#                                                   1532780983    2
#                                                   1917893285    2
#                                                   3126498597    2
#                                                   3964765198    2
#                                                   3969520793    2
#                                                   4009217263    2
#                                                   4100248998    2
#                                                   4238799154    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              93982112    regionprofile
#                                                   102060332   regionprofile
#                                                   352801846   regionprofile
#                                                   1010932979  regionprofile
#                                                   1178430311  regionprofile
#                                                   1258916736  regionprofile
#                                                   1423590944  regionprofile
#                                                   1532780983  regionprofile
#                                                   1917893285  regionprofile
#                                                   3126498597  regionprofile
#                                                   3964765198  regionprofile
#                                                   3969520793  regionprofile
#                                                   4009217263  regionprofile
#                                                   4100248998  regionprofile
#                                                   4238799154  regionprofile
# {'name': 
#                                                   102060332                comm
#                                                   352801846                comm
#                                                   1010932979               comm
#                                                   1178430311               comm
#                                                   1258916736               comm
#                                                   1423590944               comm
#                                                   1532780983               comm
#                                                   1917893285               comm
#                                                   3126498597               comm
#                                                   3964765198               comm
#                                                   3969520793               comm
#                                                   4009217263               comm
#                                                   4100248998               comm
#                                                   4238799154               comm
# {'name': 'comm_large', 'type': 'function'}        93982112           comm_large
#                                                   102060332          comm_large
#                                                   352801846          comm_large
#                                                   1010932979         comm_large
#                                                   1178430311         comm_large
#                                                   1258916736         comm_large
#                                                   1423590944         comm_large
#                                                   1532780983         comm_large
#                                                   1917893285         comm_large
#                                                   3126498597         comm_large
#                                                   3964765198         comm_large
#                                                   3969520793         comm_large
#                                                   4009217263         comm_large
#                                                   4100248998         comm_large
#                                                   4238799154         comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        93982112           cudaMemcpy
#                                                   102060332          cudaMemcpy
#                                                   352801846          cudaMemcpy
#                                                   1010932979         cudaMemcpy
#                                                   1178430311         cudaMemcpy
#                                                   1258916736         cudaMemcpy
#                                                   1423590944         cudaMemcpy
#                                                   1532780983         cudaMemcpy
#                                                   1917893285         cudaMemcpy
#                                                   3126498597         cudaMemcpy
#                                                   3964765198         cudaMemcpy
#                                                   3969520793         cudaMemcpy
#                                                   4009217263         cudaMemcpy
#                                                   4100248998         cudaMemcpy
#                                                   4238799154         cudaMemcpy
# {'name': 'comp', 'type': 'function'}              93982112                 comp
#                                                   102060332                comp
#                                                   352801846                comp
#                                                   1010932979               comp
#                                                   1178430311               comp
#                                                   1258916736               comp
#                                                   1423590944               comp
#                                                   1532780983               comp
#                                                   1917893285               comp
#                                                   3126498597               comp
#                                                   3964765198               comp
#                                                   3969520793               comp
#                                                   4009217263               comp
#                                                   4100248998               comp
#                                                   4238799154               comp
# {'name': 'comp_large', 'type': 'function'}        93982112           comp_large
#                                                   102060332          comp_large
#                                                   352801846          comp_large
#                                                   1010932979         comp_large
#                                                   1178430311         comp_large
#                                                   1258916736         comp_large
#                                                   1423590944         comp_large
#                                                   1532780983         comp_large
#                                                   1917893285         comp_large
#                                                   3126498597         comp_large
#                                                   3964765198         comp_large
#                                                   3969520793         comp_large
#                                                   4009217263         comp_large
#                                                   4100248998         comp_large
#                                                   4238799154         comp_large
# {'name': 'correctness_check', 'type': 'function'} 93982112    correctness_check
#                                                   102060332   correctness_check
#                                                   352801846   correctness_check
#                                                   1010932979  correctness_check
#                                                   1178430311  correctness_check
#                                                   1258916736  correctness_check
#                                                   1423590944  correctness_check
#                                                   1532780983  correctness_check
#                                                   1917893285  correctness_check
#                                                   3126498597  correctness_check
#                                                   3964765198  correctness_check
#                                                   3969520793  correctness_check
#                                                   4009217263  correctness_check
#                                                   4100248998  correctness_check
#                                                   4238799154  correctness_check
# {'name': 'data_init', 'type': 'function'}         93982112            data_init
#                                                   102060332           data_init
#                                                   352801846           data_init
#                                                   1010932979          data_init
#                                                   1178430311          data_init
#                                                   1258916736          data_init
#                                                   1423590944          data_init
#                                                   1532780983          data_init
#                                                   1917893285          data_init
#                                                   3126498597          data_init
#                                                   3964765198          data_init
#                                                   3969520793          data_init
#                                                   4009217263          data_init
#                                                   4100248998          data_init
#                                                   4238799154          data_init

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 93982112             2.11.0-dev
# 102060332            2.11.0-dev
# 352801846            2.11.0-dev
# 1010932979           2.11.0-dev
# 1178430311           2.11.0-dev
# 1258916736           2.11.0-dev
# 1423590944           2.11.0-dev
# 1532780983           2.11.0-dev
# 1917893285           2.11.0-dev
# 3126498597           2.11.0-dev
# 3964765198           2.11.0-dev
# 3969520793           2.11.0-dev
# 4009217263           2.11.0-dev
# 4100248998           2.11.0-dev
# 4238799154           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 93982112    min#inclusive#sum#time.duration,max#inclusive#...
# 102060332   min#inclusive#sum#time.duration,max#inclusive#...
# 352801846   min#inclusive#sum#time.duration,max#inclusive#...
# 1010932979  min#inclusive#sum#time.duration,max#inclusive#...
# 1178430311  min#inclusive#sum#time.duration,max#inclusive#...
# 1258916736  min#inclusive#sum#time.duration,max#inclusive#...
# 1423590944  min#inclusive#sum#time.duration,max#inclusive#...
# 1532780983  min#inclusive#sum#time.duration,max#inclusive#...
# 1917893285  min#inclusive#sum#time.duration,max#inclusive#...
# 3126498597  min#inclusive#sum#time.duration,max#inclusive#...
# 3964765198  min#inclusive#sum#time.duration,max#inclusive#...
# 3969520793  min#inclusive#sum#time.duration,max#inclusive#...
# 4009217263  min#inclusive#sum#time.duration,max#inclusive#...
# 4100248998  min#inclusive#sum#time.duration,max#inclusive#...
# 4238799154  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 93982112                                              2
# 102060332                                             2
# 352801846                                             2
# 1010932979                                            2
# 1178430311                                            2
# 1258916736                                            2
# 1423590944                                            2
# 1532780983                                            2
# 1917893285                                            2
# 3126498597                                            2
# 3964765198                                            2
# 3969520793                                            2
# 4009217263                                            2
# 4100248998                                            2
# 4238799154                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 93982112    cuda.gputime,node.order  regionprofile         spot
# 102060332   cuda.gputime,node.order  regionprofile         spot
# 352801846   cuda.gputime,node.order  regionprofile         spot
# 1010932979  cuda.gputime,node.order  regionprofile         spot
# 1178430311  cuda.gputime,node.order  regionprofile         spot
# 1258916736  cuda.gputime,node.order  regionprofile         spot
# 1423590944  cuda.gputime,node.order  regionprofile         spot
# 1532780983  cuda.gputime,node.order  regionprofile         spot
# 1917893285  cuda.gputime,node.order  regionprofile         spot
# 3126498597  cuda.gputime,node.order  regionprofile         spot
# 3964765198  cuda.gputime,node.order  regionprofile         spot
# 3969520793  cuda.gputime,node.order  regionprofile         spot
# 4009217263  cuda.gputime,node.order  regionprofile         spot
# 4100248998  cuda.gputime,node.order  regionprofile         spot
# 4238799154  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order                spot:output  \
# profile
# 93982112                true            true   bitonic-t128-v16384.cali
# 102060332               true            true   bitonic-t256-v16384.cali
# 352801846               true            true   bitonic-t512-v16384.cali
# 1010932979              true            true    bitonic-t128-v4096.cali
# 1178430311              true            true    bitonic-t512-v1024.cali
# 1258916736              true            true    bitonic-t512-v4096.cali
# 1423590944              true            true   bitonic-t1024-v1024.cali
# 1532780983              true            true     bitonic-t64-v4096.cali
# 1917893285              true            true    bitonic-t128-v1024.cali
# 3126498597              true            true  bitonic-t1024-v16384.cali
# 3964765198              true            true     bitonic-t64-v1024.cali
# 3969520793              true            true    bitonic-t256-v4096.cali
# 4009217263              true            true   bitonic-t1024-v4096.cali
# 4100248998              true            true    bitonic-t256-v1024.cali
# 4238799154              true            true    bitonic-t64-v16384.cali
#
#                   user  launchdate  \
# profile
# 93982112    hungry4fun  1700003522
# 102060332   hungry4fun  1700004065
# 352801846   hungry4fun  1700021556
# 1010932979  hungry4fun  1700003345
# 1178430311  hungry4fun  1700021516
# 1258916736  hungry4fun  1700021536
# 1423590944  hungry4fun  1700021656
# 1532780983  hungry4fun  1700002666
# 1917893285  hungry4fun  1700003238
# 3126498597  hungry4fun  1700021713
# 3964765198  hungry4fun  1700002474
# 3969520793  hungry4fun  1700003941
# 4009217263  hungry4fun  1700021677
# 4100248998  hungry4fun  1700003928
# 4238799154  hungry4fun  1700002767
#
#                                                     libraries  \
# profile
# 93982112    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 102060332   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 352801846   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1010932979  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1178430311  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1258916736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1423590944  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1532780983  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1917893285  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3126498597  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3964765198  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3969520793  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4009217263  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4100248998  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4238799154  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                 cmdline cluster     Algorithm  \
# profile
# 93982112     [./bitonic, 128, 16384, 1]       g  Bitonic_Sort
# 102060332    [./bitonic, 256, 16384, 1]       g  Bitonic_Sort
# 352801846    [./bitonic, 512, 16384, 1]       g  Bitonic_Sort
# 1010932979    [./bitonic, 128, 4096, 1]       g  Bitonic_Sort
# 1178430311    [./bitonic, 512, 1024, 1]       g  Bitonic_Sort
# 1258916736    [./bitonic, 512, 4096, 1]       g  Bitonic_Sort
# 1423590944   [./bitonic, 1024, 1024, 1]       g  Bitonic_Sort
# 1532780983     [./bitonic, 64, 4096, 1]       g  Bitonic_Sort
# 1917893285    [./bitonic, 128, 1024, 1]       g  Bitonic_Sort
# 3126498597  [./bitonic, 1024, 16384, 1]       g  Bitonic_Sort
# 3964765198     [./bitonic, 64, 1024, 1]       g  Bitonic_Sort
# 3969520793    [./bitonic, 256, 4096, 1]       g  Bitonic_Sort
# 4009217263   [./bitonic, 1024, 4096, 1]       g  Bitonic_Sort
# 4100248998    [./bitonic, 256, 1024, 1]       g  Bitonic_Sort
# 4238799154    [./bitonic, 64, 16384, 1]       g  Bitonic_Sort
#
#            Programming_Model Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 93982112                CUDA      int               4      16384    random
# 102060332               CUDA      int               4      16384    random
# 352801846               CUDA      int               4      16384    random
# 1010932979              CUDA      int               4       4096    random
# 1178430311              CUDA      int               4       1024    random
# 1258916736              CUDA      int               4       4096    random
# 1423590944              CUDA      int               4       1024    random
# 1532780983              CUDA      int               4       4096    random
# 1917893285              CUDA      int               4       1024    random
# 3126498597              CUDA      int               4      16384    random
# 3964765198              CUDA      int               4       1024    random
# 3969520793              CUDA      int               4       4096    random
# 4009217263              CUDA      int               4       4096    random
# 4100248998              CUDA      int               4       1024    random
# 4238799154              CUDA      int               4      16384    random
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 93982112            128         128         11            Online, AI
# 102060332           256          64         11            Online, AI
# 352801846           512          32         11            Online, AI
# 1010932979          128          32         11            Online, AI
# 1178430311          512           2         11            Online, AI
# 1258916736          512           8         11            Online, AI
# 1423590944         1024           1         11            Online, AI
# 1532780983           64          64         11            Online, AI
# 1917893285          128           8         11            Online, AI
# 3126498597         1024          16         11            Online, AI
# 3964765198           64          16         11            Online, AI
# 3969520793          256          16         11            Online, AI
# 4009217263         1024           4         11            Online, AI
# 4100248998          256           4         11            Online, AI
# 4238799154           64         256         11            Online, AI

# %%
gb = tk.groupby("InputSize")
# Out:
# 3  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2ba50a591e20>, 4096: <thicket.thicket.Thicket object at 0x2ba50a5799a0>, 16384: <thicket.thicket.Thicket object at 0x2ba50a591a60>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %% [markdown]
# ctk = th.Thicket.concat_thickets(
#     thickets=list(gb.values()),
#     headers=list(gb.keys()),
#     axis="columns",
#     metadata_key="num_threads"
# )

# %%
ctk.dataframe
# Out:
#                                                               1024  \
#                                                                nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64             1
#                                                   128            1
#                                                   256            1
#                                                   512            1
#                                                   1024           1
# {'name': 'comm', 'type': 'function'}              64             3
#                                                   128            3
#                                                   256            3
#                                                   512            3
#                                                   1024           3
# {'name': 'comm_large', 'type': 'function'}        64             4
#                                                   128            4
#                                                   256            4
#                                                   512            4
#                                                   1024           4
# {'name': 'cudaMemcpy', 'type': 'function'}        64             5
#                                                   128            5
#                                                   256            5
#                                                   512            5
#                                                   1024           5
# {'name': 'comp', 'type': 'function'}              64             6
#                                                   128            6
#                                                   256            6
#                                                   512            6
#                                                   1024           6
# {'name': 'comp_large', 'type': 'function'}        64             7
#                                                   128            7
#                                                   256            7
#                                                   512            7
#                                                   1024           7
# {'name': 'correctness_check', 'type': 'function'} 64             8
#                                                   128            8
#                                                   256            8
#                                                   512            8
#                                                   1024           8
# {'name': 'data_init', 'type': 'function'}         64             2
#                                                   128            2
#                                                   256            2
#                                                   512            2
#                                                   1024           2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.370989
#                                                   128              0.347086
#                                                   256              0.357554
#                                                   512              0.721727
#                                                   1024             0.454748
# {'name': 'comm', 'type': 'function'}              64               0.000203
#                                                   128              0.000188
#                                                   256              0.000176
#                                                   512              0.000293
#                                                   1024             0.000330
# {'name': 'comm_large', 'type': 'function'}        64               0.000146
#                                                   128              0.000127
#                                                   256              0.000116
#                                                   512              0.000209
#                                                   1024             0.000229
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000116
#                                                   128              0.000095
#                                                   256              0.000083
#                                                   512              0.000147
#                                                   1024             0.000171
# {'name': 'comp', 'type': 'function'}              64               0.001041
#                                                   128              0.001010
#                                                   256              0.000934
#                                                   512              0.001410
#                                                   1024             0.001391
# {'name': 'comp_large', 'type': 'function'}        64               0.001027
#                                                   128              0.000995
#                                                   256              0.000919
#                                                   512              0.001372
#                                                   1024             0.001354
# {'name': 'correctness_check', 'type': 'function'} 64               0.000035
#                                                   128              0.000036
#                                                   256              0.000037
#                                                   512              0.000071
#                                                   1024             0.000051
# {'name': 'data_init', 'type': 'function'}         64               0.000068
#                                                   128              0.000049
#                                                   256              0.000047
#                                                   512              0.000048
#                                                   1024             0.000046
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.370989
#                                                   128              0.347086
#                                                   256              0.357554
#                                                   512              0.721727
#                                                   1024             0.454748
# {'name': 'comm', 'type': 'function'}              64               0.000203
#                                                   128              0.000188
#                                                   256              0.000176
#                                                   512              0.000293
#                                                   1024             0.000330
# {'name': 'comm_large', 'type': 'function'}        64               0.000146
#                                                   128              0.000127
#                                                   256              0.000116
#                                                   512              0.000209
#                                                   1024             0.000229
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000116
#                                                   128              0.000095
#                                                   256              0.000083
#                                                   512              0.000147
#                                                   1024             0.000171
# {'name': 'comp', 'type': 'function'}              64               0.001041
#                                                   128              0.001010
#                                                   256              0.000934
#                                                   512              0.001410
#                                                   1024             0.001391
# {'name': 'comp_large', 'type': 'function'}        64               0.001027
#                                                   128              0.000995
#                                                   256              0.000919
#                                                   512              0.001372
#                                                   1024             0.001354
# {'name': 'correctness_check', 'type': 'function'} 64               0.000035
#                                                   128              0.000036
#                                                   256              0.000037
#                                                   512              0.000071
#                                                   1024             0.000051
# {'name': 'data_init', 'type': 'function'}         64               0.000068
#                                                   128              0.000049
#                                                   256              0.000047
#                                                   512              0.000048
#                                                   1024             0.000046
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.370989
#                                                   128              0.347086
#                                                   256              0.357554
#                                                   512              0.721727
#                                                   1024             0.454748
# {'name': 'comm', 'type': 'function'}              64               0.000203
#                                                   128              0.000188
#                                                   256              0.000176
#                                                   512              0.000293
#                                                   1024             0.000330
# {'name': 'comm_large', 'type': 'function'}        64               0.000146
#                                                   128              0.000127
#                                                   256              0.000116
#                                                   512              0.000209
#                                                   1024             0.000229
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000116
#                                                   128              0.000095
#                                                   256              0.000083
#                                                   512              0.000147
#                                                   1024             0.000171
# {'name': 'comp', 'type': 'function'}              64               0.001041
#                                                   128              0.001010
#                                                   256              0.000934
#                                                   512              0.001410
#                                                   1024             0.001391
# {'name': 'comp_large', 'type': 'function'}        64               0.001027
#                                                   128              0.000995
#                                                   256              0.000919
#                                                   512              0.001372
#                                                   1024             0.001354
# {'name': 'correctness_check', 'type': 'function'} 64               0.000035
#                                                   128              0.000036
#                                                   256              0.000037
#                                                   512              0.000071
#                                                   1024             0.000051
# {'name': 'data_init', 'type': 'function'}         64               0.000068
#                                                   128              0.000049
#                                                   256              0.000047
#                                                   512              0.000048
#                                                   1024             0.000046
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64            0.370989
#                                                   128           0.347086
#                                                   256           0.357554
#                                                   512           0.721727
#                                                   1024          0.454748
# {'name': 'comm', 'type': 'function'}              64            0.000203
#                                                   128           0.000188
#                                                   256           0.000176
#                                                   512           0.000293
#                                                   1024          0.000330
# {'name': 'comm_large', 'type': 'function'}        64            0.000146
#                                                   128           0.000127
#                                                   256           0.000116
#                                                   512           0.000209
#                                                   1024          0.000229
# {'name': 'cudaMemcpy', 'type': 'function'}        64            0.000116
#                                                   128           0.000095
#                                                   256           0.000083
#                                                   512           0.000147
#                                                   1024          0.000171
# {'name': 'comp', 'type': 'function'}              64            0.001041
#                                                   128           0.001010
#                                                   256           0.000934
#                                                   512           0.001410
#                                                   1024          0.001391
# {'name': 'comp_large', 'type': 'function'}        64            0.001027
#                                                   128           0.000995
#                                                   256           0.000919
#                                                   512           0.001372
#                                                   1024          0.001354
# {'name': 'correctness_check', 'type': 'function'} 64            0.000035
#                                                   128           0.000036
#                                                   256           0.000037
#                                                   512           0.000071
#                                                   1024          0.000051
# {'name': 'data_init', 'type': 'function'}         64            0.000068
#                                                   128           0.000049
#                                                   256           0.000047
#                                                   512           0.000048
#                                                   1024          0.000046
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.000331
#                                                   128                  0.000278
#                                                   256                  0.000260
#                                                   512                  0.000231
#                                                   1024                 0.000291
# {'name': 'comm', 'type': 'function'}              64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comm_large', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comp', 'type': 'function'}              64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'comp_large', 'type': 'function'}        64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.000331
#                                                   128                  0.000278
#                                                   256                  0.000260
#                                                   512                  0.000231
#                                                   1024                 0.000291
# {'name': 'comm', 'type': 'function'}              64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comm_large', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comp', 'type': 'function'}              64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'comp_large', 'type': 'function'}        64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.000331
#                                                   128                  0.000278
#                                                   256                  0.000260
#                                                   512                  0.000231
#                                                   1024                 0.000291
# {'name': 'comm', 'type': 'function'}              64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comm_large', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000006
#                                                   128                  0.000005
#                                                   256                  0.000005
#                                                   512                  0.000005
#                                                   1024                 0.000005
# {'name': 'comp', 'type': 'function'}              64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'comp_large', 'type': 'function'}        64                   0.000324
#                                                   128                  0.000272
#                                                   256                  0.000255
#                                                   512                  0.000226
#                                                   1024                 0.000286
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                0.000331
#                                                   128               0.000278
#                                                   256               0.000260
#                                                   512               0.000231
#                                                   1024              0.000291
# {'name': 'comm', 'type': 'function'}              64                0.000006
#                                                   128               0.000005
#                                                   256               0.000005
#                                                   512               0.000005
#                                                   1024              0.000005
# {'name': 'comm_large', 'type': 'function'}        64                0.000006
#                                                   128               0.000005
#                                                   256               0.000005
#                                                   512               0.000005
#                                                   1024              0.000005
# {'name': 'cudaMemcpy', 'type': 'function'}        64                0.000006
#                                                   128               0.000005
#                                                   256               0.000005
#                                                   512               0.000005
#                                                   1024              0.000005
# {'name': 'comp', 'type': 'function'}              64                0.000324
#                                                   128               0.000272
#                                                   256               0.000255
#                                                   512               0.000226
#                                                   1024              0.000286
# {'name': 'comp_large', 'type': 'function'}        64                0.000324
#                                                   128               0.000272
#                                                   256               0.000255
#                                                   512               0.000226
#                                                   1024              0.000286
# {'name': 'correctness_check', 'type': 'function'} 64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
# {'name': 'data_init', 'type': 'function'}         64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
#
#                                                               4096  \
#                                                                nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64             1
#                                                   128            1
#                                                   256            1
#                                                   512            1
#                                                   1024           1
# {'name': 'comm', 'type': 'function'}              64             3
#                                                   128            3
#                                                   256            3
#                                                   512            3
#                                                   1024           3
# {'name': 'comm_large', 'type': 'function'}        64             4
#                                                   128            4
#                                                   256            4
#                                                   512            4
#                                                   1024           4
# {'name': 'cudaMemcpy', 'type': 'function'}        64             5
#                                                   128            5
#                                                   256            5
#                                                   512            5
#                                                   1024           5
# {'name': 'comp', 'type': 'function'}              64             6
#                                                   128            6
#                                                   256            6
#                                                   512            6
#                                                   1024           6
# {'name': 'comp_large', 'type': 'function'}        64             7
#                                                   128            7
#                                                   256            7
#                                                   512            7
#                                                   1024           7
# {'name': 'correctness_check', 'type': 'function'} 64             8
#                                                   128            8
#                                                   256            8
#                                                   512            8
#                                                   1024           8
# {'name': 'data_init', 'type': 'function'}         64             2
#                                                   128            2
#                                                   256            2
#                                                   512            2
#                                                   1024           2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.609945
#                                                   128              0.344271
#                                                   256              0.419570
#                                                   512              0.344057
#                                                   1024             0.340919
# {'name': 'comm', 'type': 'function'}              64               0.000208
#                                                   128              0.000208
#                                                   256              0.000189
#                                                   512              0.000205
#                                                   1024             0.000184
# {'name': 'comm_large', 'type': 'function'}        64               0.000149
#                                                   128              0.000146
#                                                   256              0.000132
#                                                   512              0.000144
#                                                   1024             0.000125
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000117
#                                                   128              0.000113
#                                                   256              0.000101
#                                                   512              0.000110
#                                                   1024             0.000091
# {'name': 'comp', 'type': 'function'}              64               0.001515
#                                                   128              0.001322
#                                                   256              0.001261
#                                                   512              0.001374
#                                                   1024             0.001340
# {'name': 'comp_large', 'type': 'function'}        64               0.001499
#                                                   128              0.001306
#                                                   256              0.001247
#                                                   512              0.001356
#                                                   1024             0.001325
# {'name': 'correctness_check', 'type': 'function'} 64               0.000045
#                                                   128              0.000046
#                                                   256              0.000040
#                                                   512              0.000048
#                                                   1024             0.000045
# {'name': 'data_init', 'type': 'function'}         64               0.000131
#                                                   128              0.000111
#                                                   256              0.000112
#                                                   512              0.000113
#                                                   1024             0.000112
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.609945
#                                                   128              0.344271
#                                                   256              0.419570
#                                                   512              0.344057
#                                                   1024             0.340919
# {'name': 'comm', 'type': 'function'}              64               0.000208
#                                                   128              0.000208
#                                                   256              0.000189
#                                                   512              0.000205
#                                                   1024             0.000184
# {'name': 'comm_large', 'type': 'function'}        64               0.000149
#                                                   128              0.000146
#                                                   256              0.000132
#                                                   512              0.000144
#                                                   1024             0.000125
# {'name': 'cudaMemcpy', 'type': 'function'}        64               0.000117
#                                                   128              0.000113
#                                                   256              0.000101
#                                                   512              0.000110
#                                                   1024             0.000091
# {'name': 'comp', 'type': 'function'}              64               0.001515
#                                                   128              0.001322
#                                                   256              0.001261
#                                                   512              0.001374
#                                                   1024             0.001340
# {'name': 'comp_large', 'type': 'function'}        64               0.001499
#                                                   128              0.001306
#                                                   256              0.001247
#                                                   512              0.001356
#                                                   1024             0.001325
# {'name': 'correctness_check', 'type': 'function'} 64               0.000045
#                                                   128              0.000046
#                                                   256              0.000040
#                                                   512              0.000048
#                                                   1024             0.000045
# {'name': 'data_init', 'type': 'function'}         64               0.000131
#                                                   128              0.000111
#                                                   256              0.000112
#                                                   512              0.000113
#                                                   1024             0.000112
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64               0.609945
#                                                   128              0.344271
#                                                   256              0.419570
#                                                   512              0.344057
#                                                   1024             0.340919
# ...
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'comp', 'type': 'function'}              64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'comp_large', 'type': 'function'}        64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Min GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.000634
#                                                   128                  0.000565
#                                                   256                  0.000513
#                                                   512                  0.000514
#                                                   1024                 0.000595
# {'name': 'comm', 'type': 'function'}              64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'comm_large', 'type': 'function'}        64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'comp', 'type': 'function'}              64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'comp_large', 'type': 'function'}        64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                                  \
#                                                               Max GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.000634
#                                                   128                  0.000565
#                                                   256                  0.000513
#                                                   512                  0.000514
#                                                   1024                 0.000595
# {'name': 'comm', 'type': 'function'}              64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'comm_large', 'type': 'function'}        64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000017
#                                                   128                  0.000015
#                                                   256                  0.000015
#                                                   512                  0.000015
#                                                   1024                 0.000016
# {'name': 'comp', 'type': 'function'}              64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'comp_large', 'type': 'function'}        64                   0.000617
#                                                   128                  0.000550
#                                                   256                  0.000499
#                                                   512                  0.000499
#                                                   1024                 0.000579
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                               \
#                                                               Total GPU time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                0.000634
#                                                   128               0.000565
#                                                   256               0.000513
#                                                   512               0.000514
#                                                   1024              0.000595
# {'name': 'comm', 'type': 'function'}              64                0.000017
#                                                   128               0.000015
#                                                   256               0.000015
#                                                   512               0.000015
#                                                   1024              0.000016
# {'name': 'comm_large', 'type': 'function'}        64                0.000017
#                                                   128               0.000015
#                                                   256               0.000015
#                                                   512               0.000015
#                                                   1024              0.000016
# {'name': 'cudaMemcpy', 'type': 'function'}        64                0.000017
#                                                   128               0.000015
#                                                   256               0.000015
#                                                   512               0.000015
#                                                   1024              0.000016
# {'name': 'comp', 'type': 'function'}              64                0.000617
#                                                   128               0.000550
#                                                   256               0.000499
#                                                   512               0.000499
#                                                   1024              0.000579
# {'name': 'comp_large', 'type': 'function'}        64                0.000617
#                                                   128               0.000550
#                                                   256               0.000499
#                                                   512               0.000499
#                                                   1024              0.000579
# {'name': 'correctness_check', 'type': 'function'} 64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
# {'name': 'data_init', 'type': 'function'}         64                     NaN
#                                                   128                    NaN
#                                                   256                    NaN
#                                                   512                    NaN
#                                                   1024                   NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        64                  cudaMemcpy
#                                                   128                 cudaMemcpy
#                                                   256                 cudaMemcpy
#                                                   512                 cudaMemcpy
#                                                   1024                cudaMemcpy
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node",""),(4096, "nid"), (4096, "spot.channel"), (4096, "Min time/rank"),(4096, "Max time/rank"), (4096, "Avg time/rank"),(4096, "Avg GPU time/rank"),(4096, "Min GPU time/rank"),(4096, "Max GPU time/rank"),
                                                 (16384, "nid"), (16384, "spot.channel"), (16384, "Min time/rank"),(16384, "Max time/rank"), (16384, "Avg time/rank"),(16384, "Avg GPU time/rank"),(16384, "Min GPU time/rank"),(16384, "Max GPU time/rank"),
                                                 (1024, "nid"), (1024, "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([("index",""),(1024, "Min time/rank"), (1024, "Max time/rank"), (1024, "Avg time/rank"),(1024, "Max time/rank"), (1024, "Avg time/rank"),(1024, "Avg GPU time/rank"),(1024, "Min GPU time/rank"),(1024, "Max GPU time/rank")], axis=1)






ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
# ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
ctk.dataframe
# Out:
#                                     1024                      4096  \
#                               Total time Total GPU time Total time
# name              num_threads
# main              64            0.370989       0.000331   0.609945
#                   128           0.347086       0.000278   0.344271
#                   256           0.357554       0.000260   0.419570
#                   512           0.721727       0.000231   0.344057
#                   1024          0.454748       0.000291   0.340919
# comm              64            0.000203       0.000006   0.000208
#                   128           0.000188       0.000005   0.000208
#                   256           0.000176       0.000005   0.000189
#                   512           0.000293       0.000005   0.000205
#                   1024          0.000330       0.000005   0.000184
# comm_large        64            0.000146       0.000006   0.000149
#                   128           0.000127       0.000005   0.000146
#                   256           0.000116       0.000005   0.000132
#                   512           0.000209       0.000005   0.000144
#                   1024          0.000229       0.000005   0.000125
# cudaMemcpy        64            0.000116       0.000006   0.000117
#                   128           0.000095       0.000005   0.000113
#                   256           0.000083       0.000005   0.000101
#                   512           0.000147       0.000005   0.000110
#                   1024          0.000171       0.000005   0.000091
# comp              64            0.001041       0.000324   0.001515
#                   128           0.001010       0.000272   0.001322
#                   256           0.000934       0.000255   0.001261
#                   512           0.001410       0.000226   0.001374
#                   1024          0.001391       0.000286   0.001340
# comp_large        64            0.001027       0.000324   0.001499
#                   128           0.000995       0.000272   0.001306
#                   256           0.000919       0.000255   0.001247
#                   512           0.001372       0.000226   0.001356
#                   1024          0.001354       0.000286   0.001325
# correctness_check 64            0.000035            NaN   0.000045
#                   128           0.000036            NaN   0.000046
#                   256           0.000037            NaN   0.000040
#                   512           0.000071            NaN   0.000048
#                   1024          0.000051            NaN   0.000045
# data_init         64            0.000068            NaN   0.000131
#                   128           0.000049            NaN   0.000111
#                   256           0.000047            NaN   0.000112
#                   512           0.000048            NaN   0.000113
#                   1024          0.000046            NaN   0.000112
#
#                                                   16384
#                               Total GPU time Total time Total GPU time
# name              num_threads
# main              64                0.000436   0.438727       0.000634
#                   128               0.000381   0.326202       0.000565
#                   256               0.000406   0.338350       0.000513
#                   512               0.000379   0.340769       0.000514
#                   1024              0.000399   0.399293       0.000595
# comm              64                0.000008   0.000213       0.000017
#                   128               0.000007   0.000196       0.000015
#                   256               0.000007   0.000244       0.000015
#                   512               0.000007   0.000211       0.000015
#                   1024              0.000007   0.000200       0.000016
# comm_large        64                0.000008   0.000158       0.000017
#                   128               0.000007   0.000138       0.000015
#                   256               0.000007   0.000179       0.000015
#                   512               0.000007   0.000152       0.000015
#                   1024              0.000007   0.000147       0.000016
# cudaMemcpy        64                0.000008   0.000129       0.000017
#                   128               0.000007   0.000108       0.000015
#                   256               0.000007   0.000143       0.000015
#                   512               0.000007   0.000119       0.000015
#                   1024              0.000007   0.000116       0.000016
# comp              64                0.000428   0.001797       0.000617
#                   128               0.000374   0.001646       0.000550
#                   256               0.000398   0.001800       0.000499
#                   512               0.000372   0.001676       0.000499
#                   1024              0.000391   0.001858       0.000579
# comp_large        64                0.000428   0.001782       0.000617
#                   128               0.000374   0.001632       0.000550
#                   256               0.000398   0.001781       0.000499
#                   512               0.000372   0.001661       0.000499
#                   1024              0.000391   0.001843       0.000579
# correctness_check 64                     NaN   0.000076            NaN
#                   128                    NaN   0.000081            NaN
#                   256                    NaN   0.000089            NaN
#                   512                    NaN   0.000081            NaN
#                   1024                   NaN   0.000080            NaN
# data_init         64                     NaN   0.000373            NaN
#                   128                    NaN   0.000371            NaN
#                   256                    NaN   0.000376            NaN
#                   512                    NaN   0.000372            NaN
#                   1024                   NaN   0.000377            NaN

# %%
# var = ctk.dataframe.loc["comp_large", 1024]
# ctk.dataframe.loc["comp_large", 1024]

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = ctk.dataframe.columns.tolist()

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#                   1024                      4096                     16384  \
#             Total time Total GPU time Total time Total GPU time Total time
# num_threads
# 64            0.370989       0.000331   0.609945       0.000436   0.438727
# 128           0.347086       0.000278   0.344271       0.000381   0.326202
# 256           0.357554       0.000260   0.419570       0.000406   0.338350
# 512           0.721727       0.000231   0.344057       0.000379   0.340769
# 1024          0.454748       0.000291   0.340919       0.000399   0.399293
#
#
#             Total GPU time
# num_threads
# 64                0.000634
# 128               0.000565
# 256               0.000513
# 512               0.000514
# 1024              0.000595

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Processes",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Processes",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
speedup_df = ctk.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: thread-1/thread-N",
        xlabel="Threads",
        ylabel="Speedup",
        loglog=False
    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a546d9b773a3> in <module>
# ----> 1 speedup_df = ctk.dataframe.loc[(slice(None),1), :].reset_index().drop("threads", axis=1).set_index("name")/ctk.dataframe
#       2
#       3 for name in function_names:
#       4     plot_pandas(
#       5         df=speedup_df.loc[name],
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1095             if self._is_scalar_access(key):
#    1096                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097             return self._getitem_tuple(key)
#    1098         else:
#    1099             # we by definition only have the 0th axis
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1278         with suppress(IndexingError):
#    1279             tup = self._expand_ellipsis(tup)
# -> 1280             return self._getitem_lowerdim(tup)
#    1281
#    1282         # no multi-index, so validate all of the indexers
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     974         # we may have a nested tuples indexer here
#     975         if self._is_nested_tuple_indexer(tup):
# --> 976             return self._getitem_nested_tuple(tup)
#     977
#     978         # we maybe be using a tuple to represent multiple dimensions here
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#    1075                 continue
#    1076
# -> 1077             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078             axis -= 1
#    1079
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1334             # nested tuple slicing
#    1335             if is_nested_tuple(key, labels):
# -> 1336                 locs = labels.get_locs(key)
#    1337                 indexer = [slice(None)] * self.ndim
#    1338                 indexer[axis] = locs
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/multi.py in get_locs(self, seq)
#    3301             else:
#    3302                 # a slice or a single label
# -> 3303                 lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3304
#    3305             # update indexer
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1
