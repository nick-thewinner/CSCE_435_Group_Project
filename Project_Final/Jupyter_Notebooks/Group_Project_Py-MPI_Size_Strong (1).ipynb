# %% [markdown]
# # Group Project Thicket Python Code

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("bitonic_mpi/Bitonic_Input_Size_1048576/*.cali"))

# %%
# Performance data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              70908175      1
#                                                   133550735     1
#                                                   212775275     1
#                                                   543049715     1
#                                                   557487027     1
#                                                   1090625845    1
#                                                   1098478253    1
#                                                   1149470013    1
#                                                   1156805218    1
#                                                   1472193931    1
#                                                   1540380171    1
#                                                   1618524107    1
# ...

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 70908175             2.11.0-dev              32
# 133550735            2.11.0-dev             256
# 212775275            2.11.0-dev              64
# 543049715            2.11.0-dev              64
# 557487027            2.11.0-dev              64
# 1090625845           2.11.0-dev              16
# 1098478253           2.11.0-dev               2
# 1149470013           2.11.0-dev             256
# 1156805218           2.11.0-dev               8
# 1472193931           2.11.0-dev              32
# 1540380171           2.11.0-dev               2
# 1618524107           2.11.0-dev             256
# 1760683936           2.11.0-dev             128
# 1809759599           2.11.0-dev              32
# 1987926707           2.11.0-dev              16
# 2286178749           2.11.0-dev               4
# 2338825871           2.11.0-dev               4
# 2541343913           2.11.0-dev               2
# ...

# %%
gb = tk.groupby("InputType")
# Out:
# 4  thickets created...
# {'1% perturbation': <thicket.thicket.Thicket object at 0x2b62769a17f0>, 'random': <thicket.thicket.Thicket object at 0x2b6275c15520>, 'reverse': <thicket.thicket.Thicket object at 0x2b6275c15760>, 'sorted': <thicket.thicket.Thicket object at 0x2b6277268130>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_procs"
)

# %% [markdown]
# ctk = th.Thicket.concat_thickets(
#     thickets=list(gb.values()),
#     headers=list(gb.keys()),
#     axis="columns",
#     metadata_key="num_threads"
# )

# %%
ctk.dataframe
# Out:
#                                                             1% perturbation  \
#                                                                         nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                       1
#                                                   4                       1
#                                                   8                       1
#                                                   16                      1
#                                                   32                      1
#                                                   64                      1
#                                                   128                     1
#                                                   256                     1
# {'name': 'comm', 'type': 'function'}              2                       3
# ...

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node",""),("1% perturbation", "nid"), ("1% perturbation", "spot.channel"), ("1% perturbation", "Min time/rank"),("1% perturbation", "Max time/rank"), ("1% perturbation", "Total time"), ("1% perturbation", "Variance time/rank"),
                                                 ("random", "nid"), ("random", "spot.channel"), ("random", "Min time/rank"),("random", "Max time/rank"), ("random", "Total time"), ("random", "Variance time/rank"),
                                                    ("reverse", "nid"), ("reverse", "spot.channel"), ("reverse", "Min time/rank"),("reverse", "Max time/rank"), ("reverse", "Total time"), ("reverse", "Variance time/rank"),
                                                 ('sorted', "nid"), ('sorted', "spot.channel")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([('sorted', "Min time/rank"), ('sorted', "Max time/rank"),('sorted', "Max time/rank"), ('sorted', "Total time"), ("sorted", "Variance time/rank")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([("index",""),("level_0","")], axis=1)






ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Drop "time" label as it is redundant
# ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
ctk.dataframe
# Out:
#                             1% perturbation        random       reverse  \
#                               Avg time/rank Avg time/rank Avg time/rank
# name              num_procs
# main              2                1.265467      1.404324      1.275867
#                   4                0.728257      0.980323      0.738927
#                   8                0.666231      0.994156      0.673389
#                   16               0.837471      0.854250      0.848874
#                   32               1.394147      1.417765      1.372993
#                   64               1.356943      1.372126      1.339796
#                   128              1.448529      1.497552      1.446652
#                   256              1.851688      1.767842      1.710321
# comm              2                0.007383      0.014835      0.005337
#                   4                0.005258      0.023163      0.006275
#                   8                0.006269      0.025096      0.006698
# ...

# %%
# var = ctk.dataframe.loc["comp_large", 1024]
# ctk.dataframe.loc["comp_large", 1024]

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
matrix_sizes = ctk.dataframe.columns.tolist()

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#           1% perturbation        random       reverse        sorted
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_procs
# 2                1.265467      1.404324      1.275867      1.266813
# 4                0.728257      0.980323      0.738927      0.735479
# 8                0.666231      0.994156      0.673389      0.668201
# 16               0.837471      0.854250      0.848874      0.852717
# 32               1.394147      1.417765      1.372993      1.352098
# 64               1.356943      1.372126      1.339796      1.345888
# 128              1.448529      1.497552      1.446652      1.775027
# 256              1.851688      1.767842      1.710321      1.692618

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Processes",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Processes",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
# print(ctk.dataframe.index.levels)

speedup_df = ctk.dataframe.loc[(slice(None),2), :].reset_index().drop("num_procs", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: process-2/process-N",
        xlabel="Processes",
        ylabel="Speedup",
        loglog=False
    )
# Out:
# <ipython-input-107-3f813624407a>:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   speedup_df = ctk.dataframe.loc[(slice(None),2), :].reset_index().drop("num_procs", axis=1).set_index("name")/ctk.dataframe

# %%
 print(ctk.dataframe.index.levels)
# Out:
# [['MPI_Gather', 'MPI_Scatter', 'comm', 'comm_large', 'comp', 'comp_large', 'comp_small', 'correctness_check', 'data_init', 'main'], [2, 4, 8, 16, 32, 64, 128, 256]]
