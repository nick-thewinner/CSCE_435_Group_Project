# %% [markdown]
# # Group Project Thicket Python Code

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("Comparison_Weak/*.cali"))

# %%
# Performance data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              598256695     1
#                                                   877094456     1
#                                                   900374595     1
#                                                   1246090325    1
#                                                   1267399650    1
#                                                   1474566350    1
#                                                   1522206531    1
#                                                   2090446089    1
#                                                   2531820327    1
#                                                   2896265116    1
#                                                   2975092395    1
#                                                   3050569552    1
# ...

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 383781322            2.11.0-dev
# 540713814            2.11.0-dev
# 627804844            2.11.0-dev
# 722060376            2.11.0-dev
# 774152436            2.11.0-dev
# 860296219            2.11.0-dev
# 1418657216           2.11.0-dev
# 1508161917           2.11.0-dev
# 2029968552           2.11.0-dev
# 2130962631           2.11.0-dev
# 2518560185           2.11.0-dev
# 2727604085           2.11.0-dev
# 2940441801           2.11.0-dev
# 3406320783           2.11.0-dev
# 3494430275           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 383781322   min#inclusive#sum#time.duration,max#inclusive#...
# 540713814   min#inclusive#sum#time.duration,max#inclusive#...
# 627804844   min#inclusive#sum#time.duration,max#inclusive#...
# 722060376   min#inclusive#sum#time.duration,max#inclusive#...
# 774152436   min#inclusive#sum#time.duration,max#inclusive#...
# ...

# %%
gb = tk.groupby("Algorithm")
# Out:
# 4  thickets created...
# {'Bitonic_Sort': <thicket.thicket.Thicket object at 0x2b259a6580a0>, 'Bubble_Sort': <thicket.thicket.Thicket object at 0x2b2576017d30>, 'Merge_Sort': <thicket.thicket.Thicket object at 0x2b259a583c70>, 'Quick_Sort': <thicket.thicket.Thicket object at 0x2b259a59a580>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %% [markdown]
# ctk = th.Thicket.concat_thickets(
#     thickets=list(gb.values()),
#     headers=list(gb.keys()),
#     axis="columns",
#     metadata_key="num_threads"
# )

# %%
ctk.dataframe
# Out:
#                                                               Bitonic_Sort  \
#                                                                        nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                     1
#                                                   128                    1
#                                                   256                    1
#                                                   512                    1
#                                                   1024                   1
# {'name': 'comm', 'type': 'function'}              64                     3
#                                                   128                    3
#                                                   256                    3
#                                                   512                    3
#                                                   1024                   3
# ...

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node",""),("Bitonic_Sort", "nid"), ("Bitonic_Sort", "Avg GPU time/rank"),("Bitonic_Sort", "Max time/rank"),("Bitonic_Sort", "Total time"),("Bitonic_Sort", "Min GPU time/rank"),("Bitonic_Sort", "Max GPU time/rank"),("Bitonic_Sort", "spot.channel"), ("Bitonic_Sort", "Min time/rank"),("Bitonic_Sort", "Total GPU time"),("Merge_Sort", "Min GPU time/rank"),("Merge_Sort", "Max GPU time/rank"),
                                                 ("Bubble_Sort", "nid"), ("Bubble_Sort", "Avg GPU time/rank"),("Bubble_Sort", "Max time/rank"),("Bubble_Sort", "Total time"),("Bubble_Sort", "Min GPU time/rank"),("Bubble_Sort", "Max GPU time/rank"),("Bubble_Sort", "spot.channel"), ("Bubble_Sort", "Min time/rank"),("Bubble_Sort", "Total GPU time"),("Bubble_Sort", "Min GPU time/rank"),("Bubble_Sort", "Max GPU time/rank"),
                                                 ("Quick_Sort", "nid"), ("Quick_Sort", "Avg GPU time/rank"),("Quick_Sort", "Max time/rank"),("Quick_Sort", "Total time"),("Quick_Sort", "Min GPU time/rank"),("Quick_Sort", "Max GPU time/rank"),("Quick_Sort", "spot.channel"), ("Quick_Sort", "Min time/rank"),("Quick_Sort", "Total GPU time"),("Quick_Sort", "Min GPU time/rank"),("Quick_Sort", "Max GPU time/rank")], axis=1)
ctk.dataframe = ctk.dataframe.reset_index().drop([("index",""),("Merge_Sort","Avg GPU time/rank"),("Merge_Sort", "Total time"), ("Merge_Sort", "Max time/rank"),("Merge_Sort", "Total time"),("Merge_Sort", "Total GPU time"),("Merge_Sort", "nid"),("Merge_Sort", "spot.channel"),("Merge_Sort", "Min time/rank")], axis=1)






ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
# ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
ctk.dataframe
# Out:
#                                Bitonic_Sort   Bubble_Sort    Merge_Sort  \
#                               Avg time/rank Avg time/rank Avg time/rank
# name              num_threads
# main              64               0.438727      0.613597      0.339162
#                   128              0.326202      0.568925      0.345870
#                   256              0.338350      0.551780      0.347633
#                   512              0.340769      0.577555      0.348961
#                   1024             0.399293      0.916353      0.348421
# comm              64               0.000213      0.000243      0.000212
#                   128              0.000196      0.000219      0.000212
#                   256              0.000244      0.000228      0.000199
#                   512              0.000211      0.000257      0.000214
#                   1024             0.000200      0.000192      0.000208
# comm_large        64               0.000158      0.000178      0.000151
# ...

# %%
# var = ctk.dataframe.loc["comp_large", 1024]
# ctk.dataframe.loc["comp_large", 1024]

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = ctk.dataframe.columns.tolist()

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# ### Option 2
# Use `matplotlib.pyplot` directly for more fine-grained control. Specifically for our case we can change the x axis scaling from base 10 to base 2.

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# # Examples

# %% [markdown]
# ## time

# %%
ctk.dataframe.loc["main"]
# Out:
#              Bitonic_Sort   Bubble_Sort    Merge_Sort    Quick_Sort
#             Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_threads
# 64               0.438727      0.613597      0.339162      0.365146
# 128              0.326202      0.568925      0.345870      0.352060
# 256              0.338350      0.551780      0.347633      0.623587
# 512              0.340769      0.577555      0.348961      0.343707
# 1024             0.399293      0.916353      0.348421      0.363102

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Processes",
        ylabel="Time (seconds)",
        loglog=True
    )

# %%
for name in function_names:
    plot_mpl(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Threads",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# ## Speedup

# %%
# print(ctk.dataframe.index.levels)

speedup_df = ctk.dataframe.loc[(slice(None),64), :].reset_index().drop("num_threads", axis=1).set_index("name")/ctk.dataframe

for name in function_names:
    plot_pandas(
        df=speedup_df.loc[name],
        title=f"{name}: thread-64/thread-N",
        xlabel="Threads",
        ylabel="Speedup",
        loglog=False
    )
# Out:
# <ipython-input-16-4e94acc1117b>:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   speedup_df = ctk.dataframe.loc[(slice(None),64), :].reset_index().drop("num_threads", axis=1).set_index("name")/ctk.dataframe

# %%
 print(ctk.dataframe.index.levels)
# Out:
# [['comm', 'comm_large', 'comp', 'comp_large', 'correctness_check', 'cudaMemcpy', 'data_init', 'main'], [64, 128, 256, 512, 1024]]
